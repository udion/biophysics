# %%
import os, sys
import numpy as np
import matplotlib.pyplot as plt

# %%
f = open('../data/U00096.fna')
lines = f.readlines()
#ignoring the first line and concat everything to make a strand
lines1 = [i.strip() for i in lines[1:]]
strand = ''
for i in lines1:
    strand+=i

# %%
len(strand)
# Out:
# 4639675

# %%
stop_codons = ['TAG', 'TAA', 'TGA']
dist_offset2 = {}
dist_offset3 = {}

# %%
prev_start = 0
dist_offset1 = {}
for i in range(0,len(strand),3):
    if strand[i:i+3] in stop_codons:
        l = (i-prev_start)/3
        prev_start = i+3
        if l in dist_offset1:
            dist_offset1[l] += 1
        else:
            dist_offset1[l] = 1

# %%
x1 = sorted(dist_offset1.keys())
y1 = np.array([dist_offset1[i] for i in x1_len])
logy1 = np.log(y1)

plt.figure(figsize=(25,20))
plt.subplot(211)
plt.plot(x1, y1, 'ro')
plt.xlabel('len')
plt.ylabel('frequency')
plt.subplot(212)
plt.plot(x1, logy1, 'ro')
plt.xlabel('len')
plt.ylabel('log frequency')
# Out:
# Text(0,0.5,'log frequency')

# %%
prev_start = 1
dist_offset2 = {}
for i in range(1,len(strand),3):
    if strand[i:i+3] in stop_codons:
        l = (i-prev_start)/3
        prev_start = i+3
        if l in dist_offset2:
            dist_offset2[l] += 1
        else:
            dist_offset2[l] = 1

# %%
x2 = sorted(dist_offset2.keys())
y2 = np.array([dist_offset2[i] for i in x2])
logy2 = np.log(y2)

plt.figure(figsize=(25,20))
plt.subplot(211)
plt.plot(x2, y2, 'ro')
plt.xlabel('len')
plt.ylabel('frequency')
plt.subplot(212)
plt.plot(x2, logy2, 'ro')
plt.xlabel('len')
plt.ylabel('log frequency')
# Out:
# Text(0,0.5,'log frequency')

# %%
prev_start = 2
dist_offset3 = {}
for i in range(2,len(strand),3):
    if strand[i:i+3] in stop_codons:
        l = (i-prev_start)/3
        prev_start = i+3
        if l in dist_offset3:
            dist_offset3[l] += 1
        else:
            dist_offset3[l] = 1

# %%
x3 = sorted(dist_offset3.keys())
y3 = np.array([dist_offset3[i] for i in x3])
logy3 = np.log(y3)

plt.figure(figsize=(25,20))
plt.subplot(211)
plt.plot(x3, y3, 'ro')
plt.xlabel('len')
plt.ylabel('frequency')
plt.subplot(212)
plt.plot(x3, logy3, 'ro')
plt.xlabel('len')
plt.ylabel('log frequency')
# Out:
# Text(0,0.5,'log frequency')

# %%
plt.figure(figsize=(25,20))
plt.subplot(211)
plt.plot(x3, y3, 'ro')
plt.plot(x2, y2, 'bo')
plt.plot(x1, y1, 'go')
plt.xlabel('len')
plt.ylabel('frequency')
plt.subplot(212)
plt.plot(x3, logy3, 'ro')
plt.plot(x2, logy2, 'bo')
plt.plot(x1, logy1, 'go')
plt.xlabel('len')
plt.ylabel('log frequency')
# Out:
# Text(0,0.5,'log frequency')

# %%
plt.figure(figsize=(30,10))
plt.bar(x1,logy1)
# Out:
# <BarContainer object of 538 artists>
